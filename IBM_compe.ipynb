# %%
import numpy as np
import pandas as pd
from pandas import DataFrame, Series
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df=pd.read_csv('/content/drive/My Drive/kaggle01/IBM/data/WA_Fn-UseC_-HR-Employee-Attrition.csv')

# %% [markdown]
# # EDAを行う

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %%
#　目的変数を変換
df['Attrition'] = df['Attrition'].replace({'Yes': 1, 'No': 0})

# %%
df.head()
# Out:
#    Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0   41          1      Travel_Rarely       1102                   Sales
# 1   49          0  Travel_Frequently        279  Research & Development
# 2   37          1      Travel_Rarely       1373  Research & Development
# 3   33          0  Travel_Frequently       1392  Research & Development
# 4   27          0      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))
df['Attrition'].value_counts().plot.pie(explode=[0,0.1],autopct='%1.1f%%',ax=ax[0],shadow=True)
ax[0].set_title('Attrition')
ax[0].set_ylabel('')
sns.countplot(x=df['Attrition'],ax=ax[1])
ax[1].set_title('Attrition')
plt.show()

# %% [markdown]
# 市場分析
#
# 離職率は多いのか検討

# %% [markdown]
# 統計データから通信会社、また他分野の職種においてもかなり離職率は高い

# %% [markdown]
# [統計](https://drive.google.com/uc?id=1-BX6bo5PbQq5FFfvei3BwHdNtdS3J3HA)

# %% [markdown]
# # モデル学習

# %% [markdown]
# 特徴量を早く正確に出すためにLightGBMを使用

# %%
df.columns[df.dtypes.values == "object"]
# Out:
# Index(['BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole',
#        'MaritalStatus', 'Over18', 'OverTime'],
#       dtype='object')

# %%
categ_nominal = ['BusinessTravel', 'Department', 'EducationField', 'Gender', 'JobRole',
       'MaritalStatus', 'Over18', 'OverTime']

# %%
for i in categ_nominal:
    df = pd.concat([df, pd.get_dummies(df[i], prefix=i, dummy_na=True)], sort=False, axis=1)
df = df.drop(categ_nominal, axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Columns: 138 entries, Age to OverTime_nan
# dtypes: int64(27), uint8(111)
# memory usage: 469.5 KB

# %%
df.head()
# Out:
#    Age  Attrition  DailyRate  DistanceFromHome  Education  EmployeeCount  \
# 0   41          1       1102                 1          2              1
# 1   49          0        279                 8          1              1
# 2   37          1       1373                 2          2              1
# 3   33          0       1392                 3          4              1
# 4   27          0        591                 2          1              1
#
#    EmployeeNumber  EnvironmentSatisfaction  HourlyRate  JobInvolvement  ...  \
# 0               1                        2          94               3  ...
# 1               2                        3          61               2  ...
# 2               4                        4          92               2  ...
# 3               5                        4          56               3  ...
# 4               7                        1          40               3  ...
#
#    JobRole_nan  MaritalStatus_Divorced  MaritalStatus_Married  \
# ...

# %%
from sklearn.model_selection import train_test_split
import lightgbm as lgb

# %%
X = df.drop('Attrition',axis=1)
y = df['Attrition']
X_train, X_valid, y_train, y_valid = train_test_split(X, y,test_size=0.3, random_state=0)

# %%
# トレーニングデータと検証データを結合して重複する特徴量を確認
combined_data = pd.concat([X_train, X_valid], axis=0)
duplicated_features = combined_data.columns[combined_data.columns.duplicated()]

# 重複する特徴量を削除
X_train = X_train.drop(columns=duplicated_features)
X_valid = X_valid.drop(columns=duplicated_features)

# %%
# 学習に使用するデータを設定
lgb_train = lgb.Dataset(X_train, y_train)
lgb_eval = lgb.Dataset(X_valid, y_valid, reference=lgb_train)

# パラメータ
params = {
    'objective': 'binary',
    'metric': 'auc',
    'verbosity': -1,
}


# モデルの学習
model = lgb.train(params,
                  train_set=lgb_train, # トレーニングデータの指定
                  valid_sets=lgb_eval, # 検証データの指定
                  )

# テストデータの予測
y_pred = model.predict(X_valid)
# Out:
# [1]	valid_0's auc: 0.673931
# [2]	valid_0's auc: 0.686735
# [3]	valid_0's auc: 0.699345
# [4]	valid_0's auc: 0.677955
# [5]	valid_0's auc: 0.68635
# [6]	valid_0's auc: 0.675472
# [7]	valid_0's auc: 0.688217
# [8]	valid_0's auc: 0.674432
# [9]	valid_0's auc: 0.671429
# [10]	valid_0's auc: 0.681787
# [11]	valid_0's auc: 0.685676
# [12]	valid_0's auc: 0.682249
# [13]	valid_0's auc: 0.682095
# [14]	valid_0's auc: 0.684367
# [15]	valid_0's auc: 0.689334
# [16]	valid_0's auc: 0.688217
# [17]	valid_0's auc: 0.683211
# [18]	valid_0's auc: 0.691413
# [19]	valid_0's auc: 0.685753
# [20]	valid_0's auc: 0.691067
# [21]	valid_0's auc: 0.688756
# [22]	valid_0's auc: 0.692645
# [23]	valid_0's auc: 0.690451
# [24]	valid_0's auc: 0.694109
# [25]	valid_0's auc: 0.690759
# [26]	valid_0's auc: 0.695456
# [27]	valid_0's auc: 0.697305
# [28]	valid_0's auc: 0.695957
# [29]	valid_0's auc: 0.699153
# [30]	valid_0's auc: 0.697343
# [31]	valid_0's auc: 0.695379
# [32]	valid_0's auc: 0.693223
# ...

# %%
lgb.plot_importance(model, height=0.5, figsize=(30,40))
# Out:
# <Axes: title={'center': 'Feature importance'}, xlabel='Feature importance', ylabel='Features'>

# %% [markdown]
# # 仮説検証と提案

# %% [markdown]
# ウェルチのT検定 辞める人は、MonthlyRate,manth incomeが低い、またageは？
# 要は、毎月の評価と毎日の充実感そして年齢と予想

# %%
df.describe()
# Out:
#                Age    Attrition    DailyRate  DistanceFromHome    Education  \
# count  1470.000000  1470.000000  1470.000000       1470.000000  1470.000000
# mean     36.923810     0.161224   802.485714          9.192517     2.912925
# std       9.135373     0.367863   403.509100          8.106864     1.024165
# min      18.000000     0.000000   102.000000          1.000000     1.000000
# 25%      30.000000     0.000000   465.000000          2.000000     2.000000
# 50%      36.000000     0.000000   802.000000          7.000000     3.000000
# 75%      43.000000     0.000000  1157.000000         14.000000     4.000000
# max      60.000000     1.000000  1499.000000         29.000000     5.000000
#
#        EmployeeCount  EmployeeNumber  EnvironmentSatisfaction   HourlyRate  \
# count         1470.0     1470.000000              1470.000000  1470.000000
# mean             1.0     1024.865306                 2.721769    65.891156
# ...

# %%
ages1 = df[df['Attrition']==1]['Age']
ages0 = df[df['Attrition']==0]['Age']

# %%
var1 = stats.tvar(ages1)
var0 = stats.tvar(ages0)

# %%
print(var1, var0)
# Out:
# 93.88350139455052 79.00294393360087

# %%
print(ages1.mean(), ages0.mean())
# Out:
# 33.607594936708864 37.561232765612324

# %%
#ウェルチのT検定
from scipy import stats

# %%
stats.ttest_ind(ages1, ages0, alternative='less', equal_var=False)
# Out:
# Ttest_indResult(statistic=-5.82801185398895, pvalue=6.898800324719888e-09)

# %%
sns.barplot(x='Attrition', y='Age', data=df)
# Out:
# <Axes: xlabel='Attrition', ylabel='Age'>

# %%
df.groupby('Attrition')['Age'].plot.hist(bins=20, alpha=0.5, legend=True)
# Out:
# Attrition
# 0    Axes(0.125,0.11;0.775x0.77)
# 1    Axes(0.125,0.11;0.775x0.77)
# Name: Age, dtype: object

# %% [markdown]
# Ageについて
# 関係性はない

# %% [markdown]
# 次はincomeについて

# %%
income1 = df[df['Attrition']==1]['MonthlyIncome']
income0 = df[df['Attrition']==0]['MonthlyIncome']

# %%
income_var1 = stats.tvar(income1)
income_var0 = stats.tvar(income0)

# %%
print(income_var1)
print(income_var0)
# Out:
# 13251131.516770363
# 23215128.338823583

# %%
stats.ttest_ind(income1, income0, alternative='less', equal_var=False)
# Out:
# Ttest_indResult(statistic=-7.482621586644742, pvalue=2.2167943141430354e-13)

# %%
sns.barplot(x='Attrition', y='MonthlyIncome', data=df)
# Out:
# <Axes: xlabel='Attrition', ylabel='MonthlyIncome'>

# %%
df.groupby('Attrition')['MonthlyIncome'].plot.hist(bins=20, alpha=0.5, legend=True)
# Out:
# Attrition
# 0    Axes(0.125,0.11;0.775x0.77)
# 1    Axes(0.125,0.11;0.775x0.77)
# Name: MonthlyIncome, dtype: object

# %% [markdown]
# ここからMonthlyIncomeが高い方が辞めることはない

# %% [markdown]
# MonthlyRateについて

# %%
MonthlyRate1 = df[df['Attrition']==1]['MonthlyRate']
MonthlyRate0 = df[df['Attrition']==0]['MonthlyRate']

# %%
var_MonthlyRate1 = stats.tvar(MonthlyRate1)
var_MonthlyRate0 = stats.tvar(MonthlyRate0)

# %%
print(var_MonthlyRate1,var_MonthlyRate0)
# Out:
# 51957473.47675749 50442107.75162074

# %%
stats.ttest_ind(MonthlyRate1, MonthlyRate0, alternative='less', equal_var=False)
# Out:
# Ttest_indResult(statistic=0.5755021579649623, pvalue=0.717328085998983)

# %%
sns.barplot(x='Attrition', y='MonthlyRate', data=df)
# Out:
# <Axes: xlabel='Attrition', ylabel='MonthlyRate'>

# %%
df.groupby('Attrition')['MonthlyRate'].plot.hist(bins=20, alpha=0.5, legend=True)
# Out:
# Attrition
# 0    Axes(0.125,0.11;0.775x0.77)
# 1    Axes(0.125,0.11;0.775x0.77)
# Name: MonthlyRate, dtype: object

# %% [markdown]
# MonthlyRateは関係性はない

# %% [markdown]
# 結果

# %% [markdown]
# incomeに依存
